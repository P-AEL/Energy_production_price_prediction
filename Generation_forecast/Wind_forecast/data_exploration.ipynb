# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os
import sys

# %%
# set unlimited columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_wind = pd.read_csv(os.path.join(os.getcwd(), '..', 'data', 'wind3.csv'))
df_demand = pd.read_csv(os.path.join(os.getcwd(), '..', 'data', 'demand1.csv'))

# %%
df_wind.describe()
# Out:
#        RelativeHumidity_dwd  Temperature_dwd  WindDirection_dwd  \
# count          63573.000000     63573.000000       63573.000000
# mean              82.652115        10.690533         199.771766
# std                8.235520         3.943536          90.171106
# min               52.103130        -0.376594           1.015551
# 25%               77.202190         7.444906         142.488890
# 50%               83.681595        10.011812         212.585160
# 75%               89.110140        14.213747         265.239070
# max               99.998260        20.997318         358.847900
#
#        WindDirection:100_dwd  WindSpeed^3_dwd  WindSpeed:100^3_dwd  \
# count           63573.000000     63573.000000         63573.000000
# mean              201.491562         7.701654          1622.988327
# std                90.164790         3.880453          2247.535024
# min                 1.211598         0.290460             0.029900
# 25%               145.441930         4.623151           210.211090
# 50%               215.330860         7.442304           762.315700
# 75%               266.623350        10.478337          2161.952600
# max               359.136440        26.844606         46376.920000
#
#        WindSpeed_dwd  WindSpeed:100_dwd  WindSpeed^3:100_dwd  \
# count   63573.000000       63573.000000         63573.000000
# mean        7.670934           9.606087             9.640963
# std         3.895409           4.831118             4.815680
# min         0.223858           0.244201             0.310378
# 25%         4.587048           5.899614             5.937580
# 50%         7.409594           9.093458             9.129113
# 75%        10.465128          12.881593            12.903543
# max        26.820340          35.885605            35.928078
#
#        RelativeHumidity_ncep  Temperature_ncep  WindDirection_ncep  \
# count           63573.000000      63573.000000        63573.000000
# mean               81.651608         10.334019          199.777203
# std                 9.195702          3.867381           89.301994
# min                46.411114         -0.423364            0.592095
# 25%                75.899994          7.102976          142.729500
# 50%                83.116670          9.796892          212.986850
# 75%                88.488890         13.567098          265.328980
# max                99.888885         20.894453          359.058960
#
#        WindDirection:100_ncep  WindSpeed^3_ncep  WindSpeed:100^3_ncep  \
# count            63573.000000      63573.000000          63573.000000
# mean               201.908630          7.998044           1700.890994
# std                 89.545268          3.778286           2355.551060
# min                  0.898309          0.509266              0.076817
# 25%                145.568850          5.128512            246.291030
# 50%                216.571690          7.483607            846.260130
# 75%                267.508850         10.513399           2228.280500
# max                358.523800         26.149364          35699.047000
#
#        WindSpeed_ncep  WindSpeed:100_ncep  WindSpeed^3:100_ncep           MIP  \
# count    63573.000000        63573.000000          63573.000000  63573.000000
# mean         7.937503            9.810309              9.886993    120.340291
# std          3.802171            4.805804              4.774883     92.310652
# min          0.378919            0.352996              0.425095    -77.290000
# 25%          5.060489            6.152444              6.260109     63.640000
# 50%          7.425832            9.382714              9.448181     93.450000
# 75%         10.477026           13.009687             13.054834    154.970000
# max         26.118351           32.911392             32.927002   1983.660000
#
#             Wind_MW      SS_Price       boa_MWh     DA_Price  Wind_MWh_credit  \
# count  63573.000000  63573.000000  63573.000000  63573.00000     63573.000000
# mean     563.189560    121.402896     -1.437363    124.10136       283.032143
# std      427.556651    125.288938     21.206257     97.78055       214.319880
# min        0.000000   -185.330000   -599.500000    -51.52000         0.000000
# 25%      145.196000     56.750000      0.000000     65.29000        73.116000
# 50%      501.032000     95.250000      0.000000     94.15000       252.694000
# 75%     1038.102000    159.000000      0.000000    157.37000       522.354000
# max     1192.744000   4037.800000      0.000000   2196.22000       602.174700
#
#        date_diff
# count    63573.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
